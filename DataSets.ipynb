# %%
import pandas as pd
import numpy as np

bech_data = pd.read_csv('bechdel.csv')
bech_data.head()
# Out:
#    Unnamed: 0             Released                                 Movie  \
# 0           0  2014-01-28 00:00:00                                     1
# 1           1  2012-06-08 00:00:00                            1 Out Of 7
# 2           2  1979-10-05 00:00:00                                    10
# 3           3  2008-03-07 00:00:00                           10,000 B.C.
# 4           4  2013-08-31 00:00:00  10 Habits of Highly Effective People
#
#              Genre       Budget     Revenue Trailer  Year
# 0      Documentary          NaN         0.0     NaN  2014
# 1            Drama          NaN         0.0     NaN  2012
# 2  Romantic Comedy          NaN  52134699.0     NaN  1979
# 3        Adventure  105000000.0  94784201.0     NaN  2008
# 4              NaN          NaN         0.0     NaN  2013

# %%
netflix_data = pd.read_csv('best-netflix.tsv', delimiter='\t')
netflix_data.head()
# https://www.thrillist.com/entertainment/nation/best-netflix-movies-right-now
# Out:
#               Title of Movie    Year  \
# 0               A Single Man  2009.0
# 1         The Act of Killing  2012.0
# 2  Adventures in Babysitting  1987.0
# 3          The African Queen  1951.0
# 4                    Amadeus  1984.0
#
#                           Description from Thrillest
# 0  Is life worth living after the sudden death of...
# 1  Before The Look of Silence, which earned a pla...
# 2  Chris Columbus (of Harry Potter, Mrs. Doubtfir...
# 3  The legendary John Huston directs Humphrey Bog...
# 4  Peter Shaffer's acclaimed play received the ad...

# %%
oscars_data = pd.read_csv('oscars-demographics.csv', encoding='ISO-8859-1')
oscars_data.head()
# Out:
#      unit-id  golden unit-state  trusted-judgments last-judgment-at  \
# 0  670454356   False  finalized                  3     2/10/15 2:04
# 1  670454353   False  finalized                  3     2/10/15 3:45
# 2  670454354   False  finalized                  3     2/10/15 2:03
# 3  670454355   False  finalized                  3     2/10/15 2:05
# 4  670454357   False  finalized                  3     2/10/15 1:48
#
#            birthplace  birthplace:confidence date-of-birth  \
# 0         Chicago, Il                    1.0   23-Feb-1899
# 1   Chisinau, Moldova                    1.0   30-Sep-1895
# 2   Glasgow, Scotland                    1.0    2-Feb-1886
# 3   Chisinau, Moldova                    1.0   30-Sep-1895
# 4  Salt Lake City, Ut                    1.0   23-Apr-1894
#
#    date-of-birth:confidence race-ethnicity        ...                  award  \
# 0                       1.0          White        ...          Best Director
# ...

# %%
drug_data = pd.read_csv('drug-use-by-age.csv')
drug_data.head()
# Out:
#   age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0  12  2798          3.9                3.0            1.1
# 1  13  2757          8.5                6.0            3.4
# 2  14  2792         18.1                5.0            8.7
# 3  15  2956         29.2                6.0           14.5
# 4  16  3058         40.1               10.0           22.5
#
#    marijuana-frequency  cocaine-use cocaine-frequency  crack-use  \
# 0                  4.0          0.1               5.0        0.0
# 1                 15.0          0.1               1.0        0.0
# 2                 24.0          0.1               5.5        0.0
# 3                 25.0          0.5               4.0        0.1
# 4                 30.0          1.0               7.0        0.0
#
#   crack-frequency        ...          oxycontin-use oxycontin-frequency  \
# 0               -        ...                    0.1                24.5
# ...

# %%
life_data = pd.read_csv('us-life-expectancy-by-age-2012.csv')
life_data.head()
# Out:
#   Age (years)  Probability of dying between ages x and x + 1  \
# 0         0-1                                       0.005978
# 1         1-2                                       0.000409
# 2         2-3                                       0.000270
# 3         3-4                                       0.000204
# 4         4-5                                       0.000171
#
#   Number surviving to age x Number dying between ages x and x + 1  \
# 0                   100,000                                   598
# 1                    99,402                                    41
# 2                    99,362                                    27
# 3                    99,335                                    20
# 4                    99,315                                    17
#
#   Person-years lived between ages x and x + 1  \
# 0                                      99,474
# 1                                      99,382
# 2                                      99,348
# ...

# %%
netflix_data = pd.read_csv('netflix.csv', encoding='ISO-8859-1')
netflix_data.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
imdb_data = pd.read_csv('imdb-movies.csv')
imdb_data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
nutritional_data = pd.read_csv('nutritional-facts.csv', encoding='ISO-8859-1')
nutritional_data.head()
# Out:
#                                     Food and Serving  Calories  \
# 0                                                NaN       NaN
# 1                  Asparagus, 5 spears (93 g/3.3 oz)      20.0
# 2               Bell Pepper, 1 medium (148 g/5.3 oz)      25.0
# 3            Broccoli, 1 medium stalk (148 g/5.3 oz)      45.0
# 4  Carrot, 1 carrot, 7" long,Ê1 1/4" diameter (78...      30.0
#
#    CaloriesÊfrom Fat Total Fat Total Fat.1 Sodium Sodium.1 Potassium  \
# 0                NaN       (g)       (%DV)    (g)    (%DV)       (g)
# 1                0.0         0           0      0        0       230
# 2                0.0         0           0     40        2       220
# 3                0.0       0.5           1     80        3       460
# 4                0.0         0           0     60        3       250
#
#   Potassium.1 Total Carbo-hydrate  \
# 0       (%DV)                 (g)
# 1           7                   4
# 2           6                   6
# ...

# %%
superbowl_data = pd.read_csv('super-bowl.csv')
superbowl_data.head()
# Out:
#         Date   SB  Attendance                    QB  Winner    Coach Winner  \
# 0  15-Jan-67    I       61946                    Bart Starr  Vince Lombardi
# 1  14-Jan-68   II       75546                    Bart Starr  Vince Lombardi
# 2  12-Jan-69  III       75389                    Joe Namath     Weeb Ewbank
# 3  11-Jan-70   IV       80562   Len Dawson, Mike Livingston      Hank Stram
# 4  17-Jan-71    V       79204  Earl Morrall , Johnny Unitas  Don McCafferty
#
#                Winner  Winning Pts                     QB Loser Coach Loser  \
# 0   Green Bay Packers           35                   Len Dawson  Hank Stram
# 1   Green Bay Packers           33             Daryle Lamonica   John Rauch
# 2       New York Jets           16  Earl Morrall, Johnny Unitas   Don Shula
# 3  Kansas City Chiefs           23                     Joe Kapp   Bud Grant
# 4     Baltimore Colts           16                 Craig Morton  Tom Landry
#
# ...

# %%
trump_data = pd.read_csv('trump_tweets.csv')
trump_data.head()
# Out:
#                                                 text           created_at  \
# 0  Costs on non-military lines will never come do...  02-09-2018 13:59:13
# 1  Without more Republicans in Congress we were f...  02-09-2018 13:47:28
# 2  Just signed Bill. Our Military will now be str...  02-09-2018 13:39:15
# 3  Wow! -Senator Mark Warner got caught having ex...  02-09-2018 03:22:53
# 4  Time to end the visa lottery. Congress must se...  02-08-2018 23:26:22
#
#    retweet_count  favorite_count
# 0        11536.0         44276.0
# 1        16417.0         60858.0
# 2        16191.0         70165.0
# 3        32611.0        101423.0
# 4        20784.0         82011.0
